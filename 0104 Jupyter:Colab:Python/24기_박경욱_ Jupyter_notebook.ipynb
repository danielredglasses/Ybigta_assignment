# %% [markdown]
# <font size="5"><center> **Jupyter Notebook 사용법** </center><font>

# %% [markdown]
# **2024-1 교육세션**<div style="text-align: right"> YBIGTA 23기 DE 김현호</div>
# <div style="text-align: right">(Thanks to 14기 이용하, 15기 송하룡, 16기 김지환, 17기 이동주, 18기 정재은, 19기 유임성, 20기 금종연, 21기 박제연, 22기 김진형)</div>

# %% [markdown]
# ---
# #### * 익명질문 - 카카오톡 오픈채팅방 이용!
# #### * 함께 공부하면 좋은 사이트
# - [점프 투 파이썬](https://wikidocs.net/book/1) : 파이썬에 대한 아주 기본적인 내용을 위키백과형식으로 정리해두었습니다.
# - [codecademy](https://www.codecademy.com/learn/learn-python) : 직접 코드를 실행시켜가면서 배우는 온라인 파이썬 강의입니다.
# - [DataCamp](https://campus.datacamp.com/courses/intro-to-python-for-data-science/) : 데이터 분석을 위한 파이썬을 압축적으로 들을 수 있는 강의입니다.
# - [Programmers - Python 입문](https://programmers.co.kr/learn/courses/2) : 온라인 강의를 듣고 관련된 코드를 바로 연습해볼 수 있는 사이트입니다.

# %% [markdown]
# ----
#
# ### 1.  셀
# Jupyter Notebook에서는 블록 단위로 코드를 작성하며 이러한 블록을 __셀__ 이라고 합니다.
#
# 편집시에 기본적으로 두가지 모드가 있습니다
# 1.  Command mode 셀 선택 모드
# - ESC를 눌러서 command mode로 들어가기
# 2.  Edit mode 코드 입력 모드
# - Enter를 눌러서 코드 수정

# %% [markdown]
# 셀에는 두가지 종류가 있습니다
# 1. 코드 Cell
# 2. 마크다운 Cell

# %% [markdown]
# #### - Command mode에서 유용한 단축키들 ( Help - Keyboard Shortcuts )
# #### - **ESC** 를 누르고 나서 사용해야 합니다.
#
# - **A** : 바로 위에 새로운 Cell 생성
#
# - **B** : 바로 밑에 새로운 Cell 생성
#
# - **DD** : 해당 셀을 삭제합니다.
#
# - **Z** : 삭제한 셀을 다시 생성
#
# - **Y** : 셀을 Python Code 셀로 지정
#
# - **M** : 셀을 글 작성을 위한 Markdown 셀로 지정
#
# - **C** : 선택한 셀 복사
#
# - **V** : 복사된 셀 붙여넣기
#
# ※ 위의 단축키들은 해당 셀이 파란색 테두리일때만 사용가능합니다. 초록색인 경우, ESC를 누르거나 왼쪽의 여백을 누르시면 파란색으로 바뀝니다.
#
# - **Shift + Enter** : 해당 셀 실행

# %% [markdown]
# ----
#
# #### 2.  Markdown (단축키 M)
# 프로젝트의 진행과정을 매우 상세하게 기록할 수 있습니다.
# <br>**\#**을 통해 **글자의 크기**를 조절할 수 있고 (각 열의 맨 앞에서 사용 가능),
# <br>별표시(\*)를 양쪽에 붙여서 '**강조하기** (\*\*단어\*\* 혹은 \_\_단어\_\_)' 와 '*기울이기* (\*단어\*)'가 가능합니다.
#
#
# 참고로 Markdown이 아닌 Python Code 셀에서 #은 주석처리를 위해 사용됩니다.</p>
# - 기타 마크 다운 사용법 참고 : <https://gist.github.com/ihoneymon/652be052a0727ad59601>

# %% [markdown]
# ### - Markdown Examples

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
#
#
#
#
#
# # YBIGTA

# %% [markdown]
# ## YBIGTA

# %% [markdown]
# ### YBIGTA

# %% [markdown]
# #### YBIGTA

# %% [markdown]
# **YBIGTA**
# __YBIGTA__

# %% [markdown]
# *YBIGTA*

# %% [markdown]
# ----

# %%
# 소속, 이름, 가고싶은 팀을 적어주세요!
ybigta = "와이빅타_{박경욱}_{DS}"

# %%
# 실행해보세요
ybigta
# Out:
# '와이빅타_{박경욱}_{DS}'

# %% [markdown]
# # Python 과제

# %% [markdown]
# ## 과제 1
#
# **튜플**을 오름차순 정렬해서 리스트로 반환하는 함수를 만들어주세요.
# ```sorted()``` 함수는 금지입니다. 버블 정렬, 삽입 정렬, 퀵 정렬 등 원하는 정렬 알고리즘을 선택해주세요
#
#
# ```python3
# tup = (3, 4, 1)
# lst = sort(tup)
# # [1, 3, 4]가 나와야 함
# print(lst)
# ```

# %%
def sort(tup):
    # 이 부분은 지우지 말아주세요
    if not isinstance(tup, tuple):
        raise TypeError("tuple을 넣어주세요")
    
    # pass를 지우고 코드를 채워주세요
    tup = list(tup)
    for i in range(len(tup)):
        for j in range(i, 0, -1):
            if tup[j] < tup[j-1]:
                tup[j], tup[j-1] = tup[j-1], tup[j]
            else:
                break
    return tup

# %%
# 결과확인
tup = (8, 9, 1, 3, 11)
print(sort(tup))

# 코드 한 줄 설명: (짧은 설명을 적어주세요!)
# Used insertion sort to implement sorting algorithm
# Out:
# [1, 3, 8, 9, 11]

# %% [markdown]
# ## 과제 2
#
# 1. 'Point' 라는 이름의 클래스를 만들어 주세요.
#
# 2. 'Point' 클래스는 0이 아닌 정수 x와 y를 인스턴스 변수를 생성자에 입력 받습니다.
#
# 3. 'Point' 클래스는 위치를 set하는 함수 ```set_position(x, y)```이 있습니다.
#
# 4. 'Point' 클래스는 위치를 get하는 함수 ```get_position()```이 있습니다.
#
# 5. 'Point' 클래스는 다른 Point instance와의 거리를 계산하는 ```get_dist()``` 함수가 있습니다.
#
# 6. 'Point' 클래스는 ```print(Point)```를 했을 때 Point(x: x, y: y)를 출력해야합니다.

# %%
from math import sqrt

class Point:
    # pass를 지우고 클래스를 완성해주세요!!

    def __init__(self, x, y):
        if not isinstance(x, int) or not isinstance(y, int):
            raise TypeError("x and y coordinates need to be integer.")
        if x == 0 or y == 0:
            raise ValueError("x and y should not be 0.")
        
        self.x = x
        self.y = y

    def set_position(self, x, y):
        if not isinstance(x, int) or not isinstance(y, int):
            raise TypeError("x and y coordinates need to be integer.")
        if x == 0 or y == 0:
            raise ValueError("x and y should not be 0.")

        self.x = x
        self.y = y

    def get_position(self):
        print(f'x: {self.x}, y: {self.y}')

    def get_dist(self, p1):
        dx, dy = self.x - p1.x, self.y - p1.y
        return sqrt(dx * dx + dy * dy)

    def __str__(self):
        return f'Point(x: {self.x}, y: {self.y})'

# %%
# 출력
# x: 1, y: 2
p1 = Point(1, 2)
# p1.get_point()
p1.get_position()

# 출력
# x: 10, y: 20
# p1.set_point(10,20)
# p1.get_point()
p1.set_position(10, 20)
p1.get_position()

# (10, 20)과 (3, 4)의 유클리디안 거리를 계산해주세요
p2 = Point(3, 4)
print(p1.get_dist(p2))

print(p1)
print(p2)

# 코드 한 줄 설명: (짧은 설명을 적어주세요!)
# Used TypeError and ValueError in order to check if the inputs are valid and used sqrt to calculate the distance between two points.
# Out:
# x: 1, y: 2
# x: 10, y: 20
# 17.46424919657298
# Point(x: 10, y: 20)
# Point(x: 3, y: 4)

# %% [markdown]
# **과제하시느라 수고하셨습니다!!!**
